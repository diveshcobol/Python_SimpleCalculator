# %%
from traceback import print_tb

from win32ui import types

#Basic Syntax
#Case sensitivity - Python is case sensitive language
#Indentation
print("Hello World")

#Variable
#Data Types
#Operators
# Out:
# Hello World

# %%
age=32
print(age)
# Out:
# 32

# %%
#Variable
'''
 a variable is a symbolic name that refers to a value stored in the computer's memory. It acts as a container or placeholder for data, allowing you to store and manipulate information within your program.
'''

a=100
#a is a variable
#Assigning a variable
age=26
height=5.11
name="Divesh Bari"
is_student=True
_bloodgroup = "o+"

#printing Varibale
print("age=",age)

'''
print(height)
print(name)
print(is_student)
'''
# Out:
# age= 26
# '\nprint(height)\nprint(name)\nprint(is_student)\n'

# %%
print("age=",age)
print("height",height)
print("name=",name)
print("is_student=",is_student)
print("_bloodgroup=",_bloodgroup)


print("age =", age)
print("height =", height)
print("name =", name)
print("is_student =", is_student)
print("_bloodgroup =", _bloodgroup)

_bloodgroup = "o+"
print("_bloodgroup",_bloodgroup)
# Out:
# age= 26
# height 5.11
# name= Divesh Bari
# is_student= True
# _bloodgroup= o+
# age = 26
# height = 5.11
# name = Divesh Bari
# is_student = True
# _bloodgroup = o+
# _bloodgroup o+

# %%
_bloodgroup = "o+"
print("_bloodgroup",_bloodgroup)
# Out:
# _bloodgroup= o+

# %%
'''
naming convention
variable should be descriptitve
they must be start with letter or an underscore '_', and contains letter number and underscore
variable are case sensitive

1Valid and invalid Variable decaration anad error
types
'''
first_name='Divesh'
Last_name='Bari'

#---------------
_first_name='Divesh'
'''
3firstname="divesh"  --> invalid decimal literal

@firstname='Divesh' ---> invalid syntax. Maybe you meant '==' or ':=' instead of '='?

'''
#case sensitive

name = "Divesh"
Name = "Sunil"
NAME = "Bari"

print(name)   # Output: Divesh
print(Name)   # Output: Sunil
print(NAME)   # Output: Bari

'''
name = "Divesh"

print(Name)  # This will raise an error!incomplete input


'''
# Out:
#   Cell In[59], line 38
#     '''
#     ^
# SyntaxError: incomplete input

# %%
'''Understanding of variable types
Python is a dynamically typed language.


x = 10         # Python understands x is an int
print(type(x)) # Output: <class 'int'>

x = "hello"    # Now x is a string!
print(type(x)) # Output: <class 'str'>

x = 3.14       # Now it's a float
print(type(x)) # Output: <class 'float'>
'''
age=26  --> int
height=5.11  --> float
name="Divesh"  --> string
is_student=True --> boolean

print(type(age))
print(type(height))
print(type(name))
print(type(is_student))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>

# %%
'''
type checking
age=26
print(type(age))
and conversion

'''

age=26
print(type(age))

#type Convserion


a = 10        # int
b = 2.5       # float

result = a + b
print(result)         # Output: 12.5
print(type(result))

# Output: <class 'float'>


x = "3.14"
y = float(x)
print(y, type(y))     # Output: 3.14 <class 'float'>
# Out:
# <class 'int'>
# 12.5
# <class 'float'>
# 3.14 <class 'float'>

# %%
x = "3.14"
y = float(x)
print(type(x))
print(y, type(y))     # Output: string to float 3.14 <class 'float'>
# Out:
# <class 'str'>
# 3.14 <class 'float'>

# %%
#covert float to str

height=3.11
h1=str(height)
print(h1,type(h1))
# Out:
# 3.11 <class 'str'>

# %%
#float to int

height= 5.11
h2=int(height)
print(h2,type(h2))
# Out:
# 5 <class 'int'>

# %%
#Dynamaic Typing
var=10
print(type(var))
var=3.14
print(type(var))
var="Divesh"
print(type(var))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>

# %%
#input

age=("What is the age")
print(age)
# Out:
# What is the age

# %%
print("******  Mini Calculator  ******")
# Out:
# ******  Mini Calculator  ******

# %%
print("******  Mini Calculator  ******")
Num1=float(input("Enter the first number: "))
Num2=float(input("Enter the second number: "))
# Out:
# ******  Mini Calculator  ******
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[130], line 2
#       1 print("******  Mini Calculator  ******")
# ----> 2 Num1=float(input("Enter the first number: "))
#       3 Num2=float(input("Enter the second number: "))
#
# ValueError: could not convert string to float: '1\n\n2\n\n3'

# %%
print("******  Mini Calculator  ******")
Num1=float(input("Enter the first number: "))
Num2=float(input("Enter the second number: "))
print("press 1 for Addition\n press2 for Substraction\n press3 for Multiplication\n press4 for Division")
# Out:
# ******  Mini Calculator  ******
# press 1 for Addition
#  press2 for Substraction
#  press3 for Multiplication
#  press4 for Division

# %%
print("******  Mini Calculator  ******")
Num1=float(input("Enter the first number: "))
Num2=float(input("Enter the second number: "))
print("press 1 for Addition\n press2 for Substraction\n press3 for Multiplication\n press4 for Division")
choice=int(input("Enter your choice from 1-4: "))
if choice==1:
    print(Num1+Num2)
elif choice==2:
    print(Num2-Num2)
elif choice==3:
    print(Num1*Num2)
elif choice==4:
    print(Num1/Num2)
else:
    print("invalid choice")
# Out:
# ******  Mini Calculator  ******
# press 1 for Addition
#  press2 for Substraction
#  press3 for Multiplication
#  press4 for Division
# 9.0
